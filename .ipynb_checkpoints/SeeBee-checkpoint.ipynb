# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import numpy as np
import re

# %%
BS_file= "../Desktop/BeeState.csv"

BS_df= pd.read_csv(BS_file)

BS_df.head()
# Out:
#    Year        Period  Week Ending       State  State ANSI  Watershed  \
# 0  2017  JAN THRU MAR          NaN     ALABAMA           1        NaN
# 1  2017  JAN THRU MAR          NaN     ARIZONA           4        NaN
# 2  2017  JAN THRU MAR          NaN    ARKANSAS           5        NaN
# 3  2017  JAN THRU MAR          NaN  CALIFORNIA           6        NaN
# 4  2017  JAN THRU MAR          NaN    COLORADO           8        NaN
#
#           Data Item    Value  CV (%)
# 0  ADDED & REPLACED      570     NaN
# 1  ADDED & REPLACED    2,900     NaN
# 2  ADDED & REPLACED      430     NaN
# 3  ADDED & REPLACED  215,000     NaN
# 4  ADDED & REPLACED      100     NaN

# %%
BeeLoss_file= "../Desktop/BeeC.csv"
BeeLoss_df = pd.read_csv(BeeLoss_file)
BeeLoss_df.head()
# Out:
#       Year  Season          State  Total Annual Loss   Beekeepers  \
# 0  2016/17  Annual  Massachusetts             15.90%           87
# 1  2016/17  Annual        Montana             17.10%           21
# 2  2016/17  Annual         Nevada             23.00%           13
# 3  2016/17  Annual          Maine             23.30%           65
# 4  2016/17  Annual        Wyoming             23.40%           18
#
#    Beekeepers Exclusive to State   Colonies  Colonies Exclusive to State  \
# 0                         94.30%      27186                        2.30%
# 1                         52.40%      35905                        0.30%
# 2                         92.30%       2512                        5.20%
# 3                         93.80%      41102                        1.40%
# 4                         77.80%       6521                        1.40%
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
Varroa_file= "../Downloads/VarroaD.csv"
Varroa_df= pd.read_csv(Varroa_file, encoding= 'cp1252')
Varroa_df['References'] = Varroa_df['References'].str.replace(r'\D', '')
Varroa_df.head()
# Out:
#      Region  Latitude  Longitude   Extent Last Reported Origin First Reported  \
# 0   Algeria      28.0        3.0  Present             -      -              -
# 1     Libya      28.0       17.0  Present             -      -              -
# 2  Zimbabwe     -19.0       29.0  Present             -      -              -
# 3      Iran      32.0       53.0  Present             -      -              -
# 4      Iraq      33.0       44.0  Present             -      -              -
#
#   Invasiveness        References                      Notes
# 0            -  2009200420002002                          -
# 1            -              1979  In Sandford et al. (2007)
# 2            -              2009                          -
# 3            -      200919792006                          -
# 4            -              2009                          -

# %%
GlobalW_file= "../Downloads/NH.Ts+dSST.csv"
GlobalW_df = pd.read_csv(GlobalW_file)
GlobalW_df.head()
# Out:
#                                                                                           Land-Ocean: Northern Hemispheric Means
# Year Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  J-D  D-N  DJF  MAM  JJA                                     SON
# 1880 -.34 -.50 -.23 -.29 -.05 -.15 -.17 -.25 -.22 -.30 -.42 -.39 -.28 ***  ***  -.19 -.19                                   -.31
# 1881 -.30 -.21 -.03 .01  .04  -.32 .09  -.03 -.25 -.42 -.35 -.22 -.16 -.18 -.30 .01  -.08                                   -.34
# 1882 .28  .23  .03  -.30 -.24 -.28 -.26 -.13 -.23 -.51 -.31 -.67 -.20 -.16 .10  -.17 -.22                                   -.35
# 1883 -.56 -.64 -.14 -.29 -.24 -.10 -.04 -.21 -.32 -.15 -.44 -.14 -.27 -.32 -.62 -.23 -.12                                   -.30

# %%
DataO_file = "../Downloads/occurrence_0.csv"
DataO_df = pd.read_csv(DataO_file, encoding= 'cp1252', low_memory=False)
DataO_df.head()
# Out:
#       gbifID institutionCode collectionCode      basisOfRecord  \
# 0  699384454        USDA-ARS           BBSL  PreservedSpecimen
# 1  699384455        USDA-ARS           BBSL  PreservedSpecimen
# 2  699384456        USDA-ARS           BBSL  PreservedSpecimen
# 3  699384457        USDA-ARS           BBSL  PreservedSpecimen
# 4  699384458        USDA-ARS           BBSL  PreservedSpecimen
#
#    informationWithheld catalogNumber  recordNumber recordedBy    year  month  \
# 0                  NaN  USNM00741084           NaN        NaN  1945.0    5.0
# 1                  NaN  USNM00741085           NaN        NaN  1948.0    5.0
# 2                  NaN  USNM00741427           NaN        NaN  1947.0    7.0
# 3                  NaN  USNM00741380           NaN        NaN  1948.0    6.0
# 4                  NaN    BBSL798635           NaN  J.B. Koch  2010.0    8.0
#
#    ...   kingdom      phylum    class        order  family   genus subgenus  \
# ...

# %%
SiteV_file = "../Downloads/rspb20172140supp1.csv"
SiteV_df = pd.read_csv (SiteV_file, encoding= 'cp1252')
SiteV_df.head()
# Out:
#    Study #           Network  \
# 0      1.0          Abe 2011
# 1      2.0       Aguiar 2003
# 2      3.0      Alarcón 2008
# 3      4.0  Albrecht J. 2014
# 4      5.0  Albrecht M. 2010
#
#                                            Reference  Latitude  Longitude  \
# 0  Abe T, Wada K, Kato Y, Makino S, Okochi I. 201...     27.07     142.21
# 1  Aguiar CML. 2003 The use of floral resources b...    -12.70     -39.77
# 2  Alarcón R, Waser NM, Ollerton J. 2008 Year-to-...     34.22    -116.95
# 3  Albrecht J, Berens DG, Jaroszewicz B, Selva N,...     52.70      23.85
# 4  Albrecht M, Riesen M, Schmid B. 2010 Plant-pol...     46.44       9.94
#
#    Altitude (m) Land category Apis native?  \
# 0         151.0        Island           No
# 1         240.0      Mainland           No
# 2        2335.4      Mainland           No
# 3         167.0      Mainland          Yes
# 4        1974.0      Mainland           No
#
#    Proportion of plant spp. visited by Apis  \
# ...

# %%
#create a filtered dataframe from specific columns

BS_df = ["Year"]
